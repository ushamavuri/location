# %%
import folium
world_map=folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
vaddadi=folium.Map(location=[17.8497, 82.8721])
vaddadi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from branca.element import Figure
fig=Figure(width=650,height=450)
map1=folium.Map(location=[ 17.8497, 82.8721],zoom_start=12,min_zoom=8,max_zoom=14)
fig.add_child(map1)
map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
fig2=Figure(width=850,height=550)
map2=folium.Map(location=[ 17.8497, 82.8721])
fig2.add_child(map2)
folium.TileLayer('Stamen Terrain').add_to(map2)
folium.TileLayer('Stamen Toner').add_to(map2)
folium.TileLayer('Stamen Water Color').add_to(map2)
folium.TileLayer('cartodbpositron').add_to(map2)
folium.TileLayer('cartodbdark_matter').add_to(map2)
folium.LayerControl().add_to(map2)
map2
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
way1=[[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316],[16.8978, 81.6748], [17.0005, 81.8040],[16.9341, 81.9555],[17.0453, 82.1691],[17.2789, 82.4013],[17.3573, 82.5443],[17.6896, 83.0024],[17.8314, 82.9340],[17.8497, 82.8721]]
way2=[[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316],[16.8978, 81.6748], [17.0005, 81.8040],[16.9341, 81.9555],[17.0453, 82.1691],[17.2789, 82.4013],[17.3573, 82.5443],[17.4324, 82.5226],[17.4952, 82.5524],[17.512883729776725, 82.579273376475],[17.6664, 82.6105],[17.8314, 82.9340]]
from branca.element import Figure
fig=Figure(width=550,height=350)
f1=folium.FeatureGroup("Vehicle 1")
f2=folium.FeatureGroup("Vehicle 2")
map=folium.Map(location=[16.780001,80.849998],tiles='cartodbpositron')
line_1=folium.vector_layers.PolyLine(way1,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(way2,popup='<b>Path of Vehicle_2</b>',tooltip='Vehicle_2',color='red',weight=10).add_to(f2)
f1.add_to(map)
f2.add_to(map)
folium.Marker(location=[17.2827,82.4010],popup='Default popup Marker1',tooltip='Click here to Annavaram temple',icon=folium.Icon(color='yellow' ,prefix='fa',icon="bell")).add_to(map)
folium.Marker(location=[17.004393,81.783325],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Rajamandry bridge</strong>',icon=folium.Icon(color='purple',prefix='glyphicon',icon='tours')).add_to(map)
folium.Marker(location=[17.7103, 83.0160],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see boojanna konda</strong>',icon=folium.Icon(color='green', prefix='fa',icon="anchor")).add_to(map)

folium.Marker(location=[16.7850, 80.8488],popup='Starting point',tooltip='Nuzvidu',icon=folium.Icon(color='blue',prefix='fa',icon='university')).add_to(map)
folium.Marker(location=[17.8497, 82.8721],popup='Destination',tooltip='vaddadi',icon=folium.Icon(color='blue',prefix='fa',icon='home')).add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: color argument of Icon should be one of: {'gray', 'pink', 'lightred', 'darkblue', 'lightblue', 'orange', 'darkgreen', 'green', 'lightgreen', 'white', 'lightgray', 'purple', 'darkpurple', 'beige', 'black', 'cadetblue', 'blue', 'darkred', 'red'}.
#   del sys.path[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...
